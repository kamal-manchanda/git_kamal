# %%
##importing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline
from collections import defaultdict
import stack_clean as t

# %%
df = pd.read_csv("./survey_results_public.csv")
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %% [markdown]
# #### Q2 Who are more satisfied?

# %%
possible_vals = ["Web developer", "Desktop applications developer", 
                 "None of these", "Mobile developer", "Desktop applications developer	",
                 "Data scientist", "Other", "DevOps specialist",
                 "Database administrator", "Embedded applications/devices developer",
                 "Graphic designer", "Other"
                ]

# %%
##Applying Function

devtype_js = t.clean_df(df,col1="DeveloperType",col2="StackOverflowSatisfaction",look_for=possible_vals)

# %%
##Object to float
devtype_js.StackOverflowSatisfaction = devtype_js.StackOverflowSatisfaction.astype(float)

# %%
## difference from mean

js_plot = (devtype_js.groupby(['DeveloperType'])[['StackOverflowSatisfaction']].mean()-devtype_js.StackOverflowSatisfaction.mean()).reset_index(drop=False)

js_plot
# Out:
#                              DeveloperType  StackOverflowSatisfaction
# 0                           Data scientist                   0.010576
# 1                   Database administrator                   0.054394
# 2           Desktop applications developer                  -0.011968
# 3                        DevOps specialist                  -0.092855
# 4  Embedded applications/devices developer                  -0.131313
# 5                         Graphic designer                  -0.016206
# 6                         Mobile developer                   0.091764
# 7                                    Other                  -0.281019
# 8                            Web developer                   0.059394

# %%
##Plot of difference in StackOverflow Satisfaction mean with overall mean
sns.barplot(x='StackOverflowSatisfaction', y='DeveloperType', data=js_plot)
